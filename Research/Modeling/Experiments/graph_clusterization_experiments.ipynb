# %%
# !pip install fasttext
# Out:
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.12.0-py3-none-any.whl (234 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.25.2)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4227137 sha256=8a6533bfdbc352665de366f73fa130a9592683401040b90a17739a960ab9c194
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.12.0

# %%
# !pip install python-louvain
# !pip install glove-python3
# Out:
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.10/dist-packages (0.16)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from python-louvain) (3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from python-louvain) (1.25.2)
# Requirement already satisfied: glove-python3 in /usr/local/lib/python3.10/dist-packages (0.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from glove-python3) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from glove-python3) (1.11.4)

# %%
import pandas as pd
from google.colab import drive
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
import numpy as np
from scipy.sparse.linalg import eigsh
from sklearn.cluster import KMeans
import plotly.graph_objects as go
from scipy.spatial import ConvexHull
import community.community_louvain as community_louvain
import fasttext.util
from tqdm import tqdm
from gensim.models import FastText
from gensim.test.utils import common_texts
from glove import Corpus, Glove

# %% [markdown]
# ## Data Preparation

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_parquet('/content/drive/MyDrive/comp_final_5years.parquet')

# %%
df_short = df[['header', 'company', 'text_clear']]

# %%
df_short
# Out:
#                                                   header company  \
# 0                          Экстренная посадка в регионах    SBER
# 1                          Экстренная посадка в регионах    VTBR
# 2                          Экстренная посадка в регионах    AFLT
# 3      "Дочка" Сбербанка назвала штраф украинского ЦБ...    SBER
# 4      Газпром - Северный поток-2 заработает с 1 янва...    GAZP
# ...                                                  ...     ...
# 50286  🔶IR Газпром: Группа «Газпром» консолидировала ...    GAZP
# 50287  ГПБ стал совладельцем завода СПГ "Газпрома" у ...    GAZP
# 50288  Сооснователь Fix Price Хачатрян продал свою до...    FIXP
# 50289  ЦБ РФ оценит трансграничные переводы физлиц, с...    QIWI
# 50290   Сооснователь Fix Price Хачатрян продал свою долю    FIXP
#
#                                               text_clear
# 0      итог год российский авиарынок москва январь in...
# 1      итог год российский авиарынок москва январь in...
# 2      итог год российский авиарынок москва январь in...
# 3      украинский дочка сбербанк назвать штраф национ...
# 4      глава газпром алексей миллер рассказать интерв...
# ...                                                  ...
# 50286  релиз группа газпром консолидировать контрольн...
# 50287  группа газпромбанк стать совладелец среднетонн...
# 50288  сооснователь fix price артем хачатряна выйти к...
# 50289  банк россия январефеврал год провести обследов...
# 50290  сооснователь fix price артем хачатряна продать...
#
# [50291 rows x 3 columns]

# %%
aggregate_text = df_short.groupby('company')['text_clear'].apply(lambda x: " ".join(x))

# %%
texts = list(aggregate_text.values)
entities = list(aggregate_text.index)

# %%
node_classes = {
    # Нефть и газ
    'MOEXOG':
    ['BANE', 'GAZP', 'LKOH', 'NVTK', 'RNFT', 'ROSN', 'SNGS', 'TATN', 'TRNF'],
    # Электроэнергетики
    'MOEXEU': [
        'IRAO', 'HYDR', 'FEES', 'MSNG', 'UPRO', 'LSNG', 'RSTI', 'OGKB', 'MRKP',
        'MRKC', 'ELFV', 'TGKA', 'MSRS', 'MRKU', 'TGKB', 'DVEC', 'MRKZ', 'MRKV'
    ],
    # Телекоммуникации
    'MOEXTL': ['MTSS', 'RTKM', 'MGTS', 'TTLK'],
    # Металлы и добыча
    'MOEXMM': [
        'GMKN', 'PLZL', 'CHMF', 'NLMK', 'POLY', 'ALRS', 'MAGN', 'RUAL', 'ENPG',
        'MTLR', 'VSMO', 'SELG', 'RASP', 'SGZH', 'CHMK'
    ],
    # Финансы
    'MOEXFN':
    ['SBER', 'TCSG', 'VTBR', 'CBOM', 'BSPB', 'QIWI', 'RENI', 'SFIN', 'AFKS'],
    # Потребительский сектор
    'MOEXCN': [
        'MGNT', 'FIVE', 'FIXP', 'AGRO', 'GEMC', 'LENT', 'BELU', 'MDMG', 'AQUA',
        'MVID', 'APTK', 'SVAV', 'WUSH', 'ABIO', 'OKEY'
    ],
    # Химия и нефтехимия
    'MOEXCH': ['PHOR', 'KAZT', 'AKRN', 'NKNC', 'KZOS'],
    # Транспорт
    'MOEXTN': ['GLTR', 'FLOT', 'AFLT', 'NMTP', 'FESH', 'NKHP', 'RKKE'],
    # Информационные технологии
    'MOEXIT': ['CIAN', 'HHRU', 'OZON', 'POSI', 'VKCO', 'YNDX'],
    # Строительные компании
    'MOEXRE': ['ETLN', 'LSRG', 'PIKK', 'SMLT']
}

# %%
node_classes_new = {}
for keys,values in node_classes.items():
    for i in values:
        node_classes_new[i] = keys
print(node_classes_new)
# Out:
# {'BANE': 'MOEXOG', 'GAZP': 'MOEXOG', 'LKOH': 'MOEXOG', 'NVTK': 'MOEXOG', 'RNFT': 'MOEXOG', 'ROSN': 'MOEXOG', 'SNGS': 'MOEXOG', 'TATN': 'MOEXOG', 'TRNF': 'MOEXOG', 'IRAO': 'MOEXEU', 'HYDR': 'MOEXEU', 'FEES': 'MOEXEU', 'MSNG': 'MOEXEU', 'UPRO': 'MOEXEU', 'LSNG': 'MOEXEU', 'RSTI': 'MOEXEU', 'OGKB': 'MOEXEU', 'MRKP': 'MOEXEU', 'MRKC': 'MOEXEU', 'ELFV': 'MOEXEU', 'TGKA': 'MOEXEU', 'MSRS': 'MOEXEU', 'MRKU': 'MOEXEU', 'TGKB': 'MOEXEU', 'DVEC': 'MOEXEU', 'MRKZ': 'MOEXEU', 'MRKV': 'MOEXEU', 'MTSS': 'MOEXTL', 'RTKM': 'MOEXTL', 'MGTS': 'MOEXTL', 'TTLK': 'MOEXTL', 'GMKN': 'MOEXMM', 'PLZL': 'MOEXMM', 'CHMF': 'MOEXMM', 'NLMK': 'MOEXMM', 'POLY': 'MOEXMM', 'ALRS': 'MOEXMM', 'MAGN': 'MOEXMM', 'RUAL': 'MOEXMM', 'ENPG': 'MOEXMM', 'MTLR': 'MOEXMM', 'VSMO': 'MOEXMM', 'SELG': 'MOEXMM', 'RASP': 'MOEXMM', 'SGZH': 'MOEXMM', 'CHMK': 'MOEXMM', 'SBER': 'MOEXFN', 'TCSG': 'MOEXFN', 'VTBR': 'MOEXFN', 'CBOM': 'MOEXFN', 'BSPB': 'MOEXFN', 'QIWI': 'MOEXFN', 'RENI': 'MOEXFN', 'SFIN': 'MOEXFN', 'AFKS': 'MOEXFN', 'MGNT': 'MOEXCN', 'FIVE': 'MOEXCN', 'FIXP': 'MOEXCN', 'AGRO': 'MOEXCN', 'GEMC': 'MOEXCN', 'LENT': 'MOEXCN', 'BELU': 'MOEXCN', 'MDMG': 'MOEXCN', 'AQUA': 'MOEXCN', 'MVID': 'MOEXCN', 'APTK': 'MOEXCN', 'SVAV': 'MOEXCN', 'WUSH': 'MOEXCN', 'ABIO': 'MOEXCN', 'OKEY': 'MOEXCN', 'PHOR': 'MOEXCH', 'KAZT': 'MOEXCH', 'AKRN': 'MOEXCH', 'NKNC': 'MOEXCH', 'KZOS': 'MOEXCH', 'GLTR': 'MOEXTN', 'FLOT': 'MOEXTN', 'AFLT': 'MOEXTN', 'NMTP': 'MOEXTN', 'FESH': 'MOEXTN', 'NKHP': 'MOEXTN', 'RKKE': 'MOEXTN', 'CIAN': 'MOEXIT', 'HHRU': 'MOEXIT', 'OZON': 'MOEXIT', 'POSI': 'MOEXIT', 'VKCO': 'MOEXIT', 'YNDX': 'MOEXIT', 'ETLN': 'MOEXRE', 'LSRG': 'MOEXRE', 'PIKK': 'MOEXRE', 'SMLT': 'MOEXRE'}

# %%
texts_f_ft = [text.split() for text in texts]

# %% [markdown]
# ## TF-IDF

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)

# %%
edges = []
similarity_mat = cosine_similarity(X)
for i in range(len(entities)):
    for j in range(i + 1, len(entities)):
        similarity = similarity_mat[i][j]
        if similarity > 0.7:
            edges.append((entities[i], entities[j], similarity))

# %%
def spectral_clusterization(G, k=9):
    A = nx.adjacency_matrix(G).todense()
    D = np.diag(np.sum(A, axis=1))
    L = D - A
    D_inv_sqrt = np.linalg.inv(np.sqrt(D))
    L_norm = D_inv_sqrt @ L @ D_inv_sqrt
    eigvals, eigvecs = eigsh(L_norm, k=k, which='SM')
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(eigvecs)
    labels = kmeans.labels_
    res = {list(G.nodes)[i]: labels[i] for i in range(len(list(G.nodes)))}
    return res

# %%
def build_graph(edges, method, title, k=9):
    valid = ['louvin', 'spectral']
    if method not in valid:
        raise ValueError("results: status must be one of %r." % valid)

    G = nx.Graph()
    G.add_nodes_from(entities)
    G.add_weighted_edges_from(edges)
    isolated_nodes = list(nx.isolates(G))
    G.remove_nodes_from(isolated_nodes)

    node_classes = node_classes_new

    # Определим цвета для классов
    class_colors = {
        'MOEXOG': 'rgba(51,51,51,1)',
        'MOEXEU': 'rgba(255,255,0,1)',
        'MOEXTL': 'rgba(102,0,153,1)',
        'MOEXMM': 'rgba(204,204,204,1)',
        'MOEXFN': 'rgba(0,153,0,1)',
        'MOEXCN': 'rgba(204,0,0,1)',
        'MOEXCH': 'rgba(204,255,0,1)',
        'MOEXTN': 'rgba(0,153,255,1)',
        'MOEXIT': 'rgba(0,51,204,1)',
        'MOEXRE': 'rgba(102,51,0,1)'
    }
    if method == 'louvin':
        partition = community_louvain.best_partition(G.to_undirected())
    else:
        partition = spectral_clusterization(G, k)

    # Получим координаты узлов с помощью spring layout
    pos = nx.kamada_kawai_layout(G)

    # Получим координаты для plotly
    edge_x = []
    edge_y = []
    weights = []
    for edge in G.edges(data=True):
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.append(x0)
        edge_x.append(x1)
        edge_x.append(None)
        edge_y.append(y0)
        edge_y.append(y1)
        edge_y.append(None)
        weights.append(edge[2]['weight'])

    # Нормализуем веса для градиента
    weights = np.array(weights)
    norm_weights = (weights - weights.min()) / (weights.max() - weights.min())

    # Создадим фигуру
    fig = go.Figure()

    # Добавим грани с градиентом
    for i in range(len(edge_x)//3):
        fig.add_trace(go.Scatter(
            x=edge_x[i*3:(i+1)*3],
            y=edge_y[i*3:(i+1)*3],
            line=dict(width=2, color=f'rgba(0,0,255,{norm_weights[i]})'),
            hoverinfo='none',
            mode='lines',
            showlegend=False
        ))

    # Определим цвета для кластеров
    clusters = list(set(partition.values()))
    cluster_colors = {cluster: f'rgba({np.random.randint(0, 255)}, {np.random.randint(0, 255)}, {np.random.randint(0, 255)}, 0.3)' for cluster in clusters}

    # Добавим области для кластеров
    for cluster in clusters:
        cluster_nodes = [node for node in G.nodes if partition[node] == cluster]
        if len(cluster_nodes) > 2:
            cluster_pos = np.array([pos[node] for node in cluster_nodes])
            hull = ConvexHull(cluster_pos)
            hull_pts = cluster_pos[hull.vertices]
            hull_x = hull_pts[:, 0]
            hull_y = hull_pts[:, 1]
            fig.add_trace(go.Scatter(
                x=hull_x.tolist() + [hull_x[0]],
                y=hull_y.tolist() + [hull_y[0]],
                fill='toself',
                fillcolor=cluster_colors[cluster],
                line=dict(color='rgba(255,255,255,0)'),
                hoverinfo='none',
                mode='lines',
                showlegend=False
            ))

    # Добавим узлы с размерами, зависящими от количества связей и цветами согласно классу
    node_x = []
    node_y = []
    node_sizes = []
    node_colors = []
    node_texts = []
    for node in pos:
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)
        node_sizes.append(10 + (G.degree(node)))  # базовый размер 10, плюс 5 за каждую связь
        node_colors.append(class_colors[node_classes[node]])
        node_texts.append(f'Node {node}: Degree {G.degree(node)}, Class {node_classes[node]}')

    fig.add_trace(go.Scatter(
        x=node_x,
        y=node_y,
        mode='markers+text',
        text=[f'{node}' for node in G.nodes],
        textposition='top center',
        marker=dict(size=node_sizes, color=node_colors),
        hoverinfo='text',
        name='Nodes',
        showlegend=False
    ))

    # Добавим легенду
    for node_class, color in class_colors.items():
        fig.add_trace(go.Scatter(
            x=[None],
            y=[None],
            mode='markers',
            marker=dict(size=10, color=color),
            legendgroup=node_class,
            showlegend=True,
            name=f'{node_class}'
        ))

    colorbar_trace = go.Scatter(
        x=[None], y=[None],
        mode='markers',
        marker=dict(
            size=10,
            color=[weights.min(), weights.max()],
            colorscale=[f'rgba(0,0,255,{sorted(norm_weights)[i]})' for i in range(len(edge_x)//3)],
            colorbar=dict(
                title='Cosine Similarity',
                titleside="right",
                tickvals=[weights.min(), weights.max()],
                ticktext=[round(weights.min(), 3), round(weights.max(), 3)],
                orientation='h',
                x=0.5,
                xanchor='center',
                y=-0.1,
                yanchor='top'
            )
        ),
        showlegend=False,
        hoverinfo='none'
    )

    fig.add_trace(colorbar_trace)


    # Настройки отображения
    fig.update_layout(showlegend=True, title_text=title, legend_title_text='Industrial Indexes')
    fig.show()

# %%
build_graph(edges, method='spectral', k=5, title='Spectral tf-idf k=5')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id
null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.5735178474422915)","width":2},"mode":"lines","showlegend":false,"x":[0.31496893790009367,0.1016253044884164,null],"y":[-0.18850927240170456,0.021581996180892057,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.1808839141339545)","width":2},"mode":"lines","showlegend":false,"x":[0.31496893790009367,0.29873670369996724,null],"y":[-0.18850927240170456,-0.03389959114140513,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.5819765648168815)","width":2},"mode":"lines","showlegend":false,"x":[ ...

# %% [markdown]
# > Louvin looks different as it splits manufacturers and electoenergy companies. Clusterization of consumer oriented compnies also looks a little different. Real estate companies somehow occured in same cluster as telecom.

# %% [markdown]
# > Tf-idf based graphs appear to be rather good, as there is a clear explanation behind each edge. These graphs allows us to split companies into several clusters in a way that make sense.

# %% [markdown]
# ## Fasttext

# %%
fasttext.util.download_model('ru', if_exists='ignore')
ft = fasttext.load_model('cc.ru.300.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
def get_text_embeddings(text):

    embeddings = [ft.get_word_vector(word) for word in text]
    return sum(embeddings) / len(embeddings)

# %%
X_emb = []

# %%
for text in tqdm(texts):
    text_embedding = get_text_embeddings(text.split())
    X_emb.append(text_embedding)
# Out:
# 100%|██████████| 91/91 [02:26<00:00,  1.61s/it]

# %%
edges = []
similarity_mat = cosine_similarity(X_emb)
for i in range(len(entities)):
    for j in range(i + 1, len(entities)):
        similarity = similarity_mat[i][j]
        if similarity > 0.99:
            edges.append((entities[i], entities[j], similarity))

# %%
build_graph(edges, method='spectral', k=5, title='Spectral FastText Pre-Trained k=5')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3df0c439-4af9-4d24-863c-7225bcf76536" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3df0c439-4af9-4d24-863c-7225bcf76536")) {                    Plotly.newPlot(                        "3df0c439-4af9-4d24-863c-7225bcf76536",                        [{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.22675757764687224)","width":2},"mode":"lines","showlegend":false,"x":[0.7425199245792515,0.5105133640334923,null],"y":[0.2556203716533076,0.32634153948144573,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.0)","width":2},"mode":"lines","showlegend":false,"x":[0.3703769909916255,0.16202607401381683,null],"y":[-0.10810350164010059,-0.11499259616346018,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.03468983770912056)","width":2},"mode":"lines","showlegend":false,"x":[0.3703769909916255,0.16309615237751937,null],"y":[-0.10810350164010059,0.08432531276582698,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.15081956822853657)","width":2},"mode":"lines","showlegend":false,"x":[0.3703769909916255,0.5677011185969009,null],"y":[-0.10810350164010059,-0.22201536919952472,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.3672734573480908)","width":2},"mode":"lines","showlegend":false,"x":[0.3703769909916255,0.1558132516420418,null],"y":[-0.10810350164010059,0.033647973411702246,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.25563055798614465)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.0648750411143997,null],"y":[-0.11499259616346018,0.06361899160485412,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.09747087030798683)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.044625245740608784,null],"y":[-0.11499259616346018,0.1380873912708868,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.08643814157669631)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,-0.04086197740110001,null],"y":[-0.11499259616346018,-0.003085071331880865,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.1739129699199)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.22920848034463512,null],"y":[-0.11499259616346018,-0.05321766527185759,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.17905347244586486)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.16309615237751937,null],"y":[-0.11499259616346018,0.08432531276582698,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.40189367832873696)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.1558132516420418,null],"y":[-0.11499259616346018,0.033647973411702246,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.025997636230052495)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.14686201050413286,null],"y":[-0.11499259616346018,0.16443252032340108,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.023084940600456884)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.0015076673122850067,null],"y":[-0.11499259616346018,-0.0110424073981066,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.5634049311717744)","width":2},"mode":"lines","showlegend":false,"x":[0.14606543746816947,0.0648750411143997,null],"y":[-0.050246425355911985,0.06361899160485412,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.
null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.40189367832873696)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.1558132516420418,null],"y":[-0.11499259616346018,0.033647973411702246,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.025997636230052495)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.14686201050413286,null],"y":[-0.11499259616346018,0.16443252032340108,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.023084940600456884)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.0015076673122850067,null],"y":[-0.11499259616346018,-0.0110424073981066,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.5634049311717744)","width":2},"mode":"lines","showlegend":false,"x":[0.14606543746816947,0.0648750411143997,null],"y":[-0.050246425355911985,0.06361899160485412,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.06243824393880361)","width":2},"mode":"lines","showlegend":false,"x":[0.14 ...

# %% [markdown]
# > It becomes worse as real estate companies represent their own cluster

# %%
build_graph(edges, method='spectral', k=11, title='Spectral FastText Pre-Trained k=11')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a7c97728-314e-4fda-ba7d-d78a18bf1e24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7c97728-314e-4fda-ba7d-d78a18bf1e24")) {                    Plotly.newPlot(                        "a7c97728-314e-4fda-ba7d-d78a18bf1e24",                        [{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.22675757764687224)","width":2},"mode":"lines","showlegend":false,"x":[0.7425199245792515,0.5105133640334923,null],"y":[0.2556203716533076,0.32634153948144573,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.0)","width":2},"mode":"lines","showlegend":false,"x":[0.3703769909916255,0.16202607401381683,null],"y":[-0.10810350164010059,-0.11499259616346018,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.03468983770912056)","width":2},"mode":"lines","showlegend":false,"x":[0.3703769909916255,0.16309615237751937,null],"y":[-0.10810350164010059,0.08432531276582698,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.15081956822853657)","width":2},"mode":"lines","showlegend":false,"x":[0.3703769909916255,0.5677011185969009,null],"y":[-0.10810350164010059,-0.22201536919952472,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.3672734573480908)","width":2},"mode":"lines","showlegend":false,"x":[0.3703769909916255,0.1558132516420418,null],"y":[-0.10810350164010059,0.033647973411702246,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.25563055798614465)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.0648750411143997,null],"y":[-0.11499259616346018,0.06361899160485412,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.09747087030798683)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.044625245740608784,null],"y":[-0.11499259616346018,0.1380873912708868,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.08643814157669631)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,-0.04086197740110001,null],"y":[-0.11499259616346018,-0.003085071331880865,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.1739129699199)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.22920848034463512,null],"y":[-0.11499259616346018,-0.05321766527185759,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.17905347244586486)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.16309615237751937,null],"y":[-0.11499259616346018,0.08432531276582698,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.40189367832873696)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.1558132516420418,null],"y":[-0.11499259616346018,0.033647973411702246,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.025997636230052495)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.14686201050413286,null],"y":[-0.11499259616346018,0.16443252032340108,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.023084940600456884)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.0015076673122850067,null],"y":[-0.11499259616346018,-0.0110424073981066,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.5634049311717744)","width":2},"mode":"lines","showlegend":false,"x":[0.14606543746816947,0.0648750411143997,null],"y":[-0.050246425355911985,0.06361899160485412,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.06243824393880361)","width":2},"mode":"lines","showlegend":false,"x":[0.14 ...

# %% [markdown]
# > Looks better, manufacturers are splitted into oil and metal companies

# %%
build_graph(edges, method='louvin', title='Louvin FastText Pre-Trained')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a604f773-d188-423d-a5b2-95bfbba5a5c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a604f773-d188-423d-a5b2-95bfbba5a5c6")) {                    Plotly.newPlot(                        "a604f773-d188-423d-a5b2-95bfbba5a5c6",                        [{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.22675757764687224)","width":2},"mode":"lines","showlegend":false,"x":[0.7425199245792515,0.5105133640334923,null],"y":[0.2556203716533076,0.32634153948144573,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.0)","width":2},"mode":"lines","showlegend":false,"x":[0.3703769909916255,0.16202607401381683,null],"y":[-0.10810350164010059,-0.11499259616346018,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.03468983770912056)","width":2},"mode":"lines","showlegend":false,"x":[0.3703769909916255,0.16309615237751937,null],"y":[-0.10810350164010059,0.08432531276582698,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.15081956822853657)","width":2},"mode":"lines","showlegend":false,"x":[0.3703769909916255,0.5677011185969009,null],"y":[-0.10810350164010059,-0.22201536919952472,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.3672734573480908)","width":2},"mode":"lines","showlegend":false,"x":[0.3703769909916255,0.1558132516420418,null],"y":[-0.10810350164010059,0.033647973411702246,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.25563055798614465)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.0648750411143997,null],"y":[-0.11499259616346018,0.06361899160485412,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.09747087030798683)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.044625245740608784,null],"y":[-0.11499259616346018,0.1380873912708868,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.08643814157669631)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,-0.04086197740110001,null],"y":[-0.11499259616346018,-0.003085071331880865,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.1739129699199)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.22920848034463512,null],"y":[-0.11499259616346018,-0.05321766527185759,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.17905347244586486)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.16309615237751937,null],"y":[-0.11499259616346018,0.08432531276582698,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.40189367832873696)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.1558132516420418,null],"y":[-0.11499259616346018,0.033647973411702246,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.025997636230052495)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.14686201050413286,null],"y":[-0.11499259616346018,0.16443252032340108,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.023084940600456884)","width":2},"mode":"lines","showlegend":false,"x":[0.16202607401381683,0.0015076673122850067,null],"y":[-0.11499259616346018,-0.0110424073981066,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.5634049311717744)","width":2},"mode":"lines","showlegend":false,"x":[0.14606543746816947,0.0648750411143997,null],"y":[-0.050246425355911985,0.06361899160485412,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.06243824393880361)","width":2},"mode":"lines","showlegend":false,"x":[0.14 ...

# %% [markdown]
# > Seems better than spectral in this case

# %% [markdown]
# > FastText pre-trained embeddings wasn't really helpful as cosine similarity between embeddings is too large and there are a lot of closely related companies in this case. However, it didn't catch some of connections, which tf-idf did (like ownership of MTSS by AFKS)

# %%
np.save('sim_matrix', similarity_mat)

# %%
np.save('embeddings', np.array(X_emb))

# %% [markdown]
# ### FastText learn

# %%
model = FastText(sentences=texts_f_ft, vector_size=300, window=5, min_count=1, workers=4, sg=1)

# %%
def get_text_embeddings(text):

    embeddings = [model.wv[word] for word in text]
    return sum(embeddings) / len(embeddings)

# %%
X_emb_2 = []

# %%
for text in tqdm(texts):
    text_embedding = get_text_embeddings(text.split())
    X_emb_2.append(text_embedding)
# Out:
# 100%|██████████| 91/91 [00:38<00:00,  2.36it/s]

# %%
edges = []
similarity_mat = cosine_similarity(X_emb_2)
for i in range(len(entities)):
    for j in range(i + 1, len(entities)):
        similarity = similarity_mat[i][j]
        if similarity > 0.998:
            edges.append((entities[i], entities[j], similarity))

# %%
build_graph(edges, method='spectral', k=5, title='Spectral FastText Trained k=5')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7faff67f-ab33-44d6-8388-8920179bbb56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7faff67f-ab33-44d6-8388-8920179bbb56")) {                    Plotly.newPlot(                        "7faff67f-ab33-44d6-8388-8920179bbb56",                        [{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.2111327339381386)","width":2},"mode":"lines","showlegend":false,"x":[0.18943284813125005,0.20553000112273845,null],"y":[0.34130580196159765,0.41070573511914743,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.5035109176834279)","width":2},"mode":"lines","showlegend":false,"x":[0.18943284813125005,0.32413814466544666,null],"y":[0.34130580196159765,0.21424392236335252,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.11875105996980546)","width":2},"mode":"lines","showlegend":false,"x":[0.18943284813125005,0.3511674320768573,null],"y":[0.34130580196159765,0.4801979969626612,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.08732500892321793)","width":2},"mode":"lines","showlegend":false,"x":[0.18943284813125005,0.36074025568080137,null],"y":[0.34130580196159765,0.3171876110217098,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.28052106614481304)","width":2},"mode":"lines","showlegend":false,"x":[0.18943284813125005,0.07522199572957598,null],"y":[0.34130580196159765,0.20949148006450674,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.23446501048534735)","width":2},"mode":"lines","showlegend":false,"x":[0.19062558868893506,-0.05184572950619127,null],"y":[-0.1529719203585076,-0.22327965593780527,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.36137298075114693)","width":2},"mode":"lines","showlegend":false,"x":[0.19062558868893506,-0.05975103532931819,null],"y":[-0.1529719203585076,-0.16367468919141193,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.0843051509328586)","width":2},"mode":"lines","showlegend":false,"x":[0.19062558868893506,0
","width":2},"mode":"lines","showlegend":false,"x":[0.18943284813125005,0.32413814466544666,null],"y":[0.34130580196159765,0.21424392236335252,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.11875105996980546)","width":2},"mode":"lines","showlegend":false,"x":[0.18943284813125005,0.3511674320768573,null],"y":[0.34130580196159765,0.4801979969626612,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.08732500892321793)","width":2},"mode":"lines","showlegend":false,"x":[0.18943284813125005,0.36074025568080137,null],"y":[0.34130580196159765,0.3171876110217098,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.28052106614481304)","width":2},"mode":"lines","showlegend":false,"x":[0.18943284813125005,0.07522199572957598,null],"y":[0.34130580196159765,0.20949148006450674,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.23446501048534735)","width":2},"mode":"lines","showlegend":false,"x":[0.19062558868893506,-0.05184572950619127,null],"y":[-0.1529719203585076,-0.22327965593780527,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.36137298075114693)","width":2},"mode":"lines","showlegend":false,"x":[0.19062558868893506,-0.05975103532931819,null],"y":[-0.1529719203585076,-0.16367468919141193,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.0843051509328586)","width":2},"mode":"lines","showlegend":false,"x":[0.19062558868893506,0.10215476673759401,null],"y":[-0.1529719203585076,-0.2002120452214043,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.327351308784671)","width":2},"mode":"lines","showlegend":false,"x":[0.19062558868893506,0.04725288292368871,null],"y":[-0.1529719203585076,-0.08034605657815168,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.06158875761852429)","width":2},"mode":"lines","showlegend":false,"x":[0.19062558868893506,0.366623880214405,null],"y":[-0.1529719203585076,-0.017894272985028447,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.20955322708364066)","width":2},"mode":"lines","showlegend":false,"x":[-0.11304444591523997,-0.24303617430867963,null],"y":[0.07244557236613719,-0.08825177878220868,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.030450051926016963)","width":2},"mode":"lines","showlegend":false,"x":[-0.11304444591523997,-0.13202819298680388,null],"y":[0.07244557236613719,-0.2775287652375936,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.12501700698325624)","width":2},"mode":"lines","showlegend":false,"x":[-0.11304444591523997,-0.32339499306706077,null],"y":[0.07244557236613719,0.1711547935177966,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.3286481423262929)","width":2},"mode":"lines","showlegend":false,"x":[-0.11304444591523997,-0.17099651297508253,null],"y":[0.07244557236613719,-0.20681847671510334,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.4335693201645086)","width":2},"mode":"lines","showlegend":fa ...

# %% [markdown]
# > There are also non-obvious clusters, it does not seem that they are meaningful

# %% [markdown]
# > Trained FastText performed even worse, embeddings are very similar

# %% [markdown]
# ## Glove learn

# %%
from glove import Corpus, Glove

# %%
corpus = Corpus()

corpus.fit(texts_f_ft, window=10)

glove = Glove(no_components=300, learning_rate=0.05)
glove.fit(corpus.matrix, epochs=30, no_threads=4, verbose=True)
glove.add_dictionary(corpus.dictionary)
glove.save('glove.model')
# Out:
# Performing 30 training epochs with 4 threads
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15
# Epoch 16
# Epoch 17
# Epoch 18
# Epoch 19
# Epoch 20
# Epoch 21
# Epoch 22
# Epoch 23
# Epoch 24
# Epoch 25
# Epoch 26
# Epoch 27
# Epoch 28
# Epoch 29

# %%
def get_text_embeddings(text):
    embeddings = [glove.word_vectors[glove.dictionary[word]] for word in text]
    return sum(embeddings) / len(embeddings)

# %%
X_emb_3 = []

# %%
for text in tqdm(texts):
    text_embedding = get_text_embeddings(text.split())
    X_emb_3.append(text_embedding)
# Out:
# 100%|██████████| 91/91 [00:19<00:00,  4.57it/s]

# %%
edges = []
similarity_mat = cosine_similarity(X_emb_3)
for i in range(len(entities)):
    for j in range(i + 1, len(entities)):
        similarity = similarity_mat[i][j]
        if similarity > 0.985:
            edges.append((entities[i], entities[j], similarity))

# %%
build_graph(edges, method='spectral', k=5, title='Spectral Glove k=5')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6a7b6a60-e66e-4eff-99b7-2323b4071fcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6
","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,0.034415327848521284,null],"y":[-0.34230983086100536,-0.2527635170256185,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.21557610509962968)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,-0.04589565218469377,null],"y":[-0.34230983086100536,-0.23657096541560166,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.04423679489580257)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,0.12076134868181015,null],"y":[-0.34230983086100536,-0.46283400405480607,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.12399039308990158)","width":2},"mode":"lines","showleg ...

# %% [markdown]
# > It is better, now banks have their own cluster, real estate companies are in one cluster, as well as telecom and it. Still, the largest cluster is still too large.

# %%
build_graph(edges, method='spectral', k=9, title='Spectral Glove k=9')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="86411a70-7b01-4c14-9ce8-c22c226b757e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86411a70-7b01-4c14-9ce8-c22c226b757e")) {                    Plotly.newPlot(                        "86411a70-7b01-4c14-9ce8-c22c226b757e",                        [{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.17628740305670396)","width":2},"mode":"lines","showlegend":false,"x":[0.12435370917482824,-0.04760656756448656,null],"y":[0.36254226154325014,0.33506172252199184,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.28609803243322685)","width":2},"mode":"lines","showlegend":false,"x":[0.12435370917482824,0.2780788793236303,null],"y":[0.36254226154325014,0.40346757767027075,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.0)","width":2},"mode":"lines","showlegend":false,"x":[0.12435370917482824,0.20319553478487068,null],"y":[0.36254226154325014,0.5412105980619433,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.3350999331972103)","width":2},"mode":"lines","showlegend":false,"x":[0.12435370917482824,0.04493687658409709,null],"y":[0.36254226154325014,0.19624715515558835,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.052108030025666795)","width":2},"mode":"lines","showlegend":false,"x":[0.0012823379175920385,-0.011780871524810022,null],"y":[0.015586430749647617,-0.17317837420766763,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.11723803913014519)","width":2},"mode":"lines","showlegend":false,"x":[0.0012823379175920385,0.04493687658409709,null],"y":[0.015586430749647617,0.19624715515558835,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.5008901401154547)","width":2},"mode":"lines","showlegend":false,"x":[0.16199407649566108,-0.011780871524810022,null],"y":[-0.12325180553085524,-0.17317837420766763,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.2740625610338989)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,-0.04955048165903646,null],"y":[-0.34230983086100536,-0.3784487061613248,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.37270945617133516)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,0.010063537408377905,null],"y":[-0.34230983086100536,-0.3730245456223892,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.17941385867790052)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,-0.011355875072672937,null],"y":[-0.34230983086100536,-0.3053295539077045,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.06610343805628066)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,-0.011780871524810022,null],"y":[-0.34230983086100536,-0.17317837420766763,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.13258470873960873)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,0.034415327848521284,null],"y":[-0.34230983086100536,-0.2527635170256185,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.21557610509962968)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,-0.04589565218469377,null],"y":[-0.34230983086100536,-0.23657096541560166,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.04423679489580257)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,0.12076134868181015,null],"y":[-0.34230983086100536,-0.46283400405480607,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.12399039308990158)","width":2},"mode":"lines","showleg ...

# %% [markdown]
# > It looks better than the previous one. Even metals and oil stood out separately. The only thing that is a little frustrating is the electric power industry

# %%
build_graph(edges, method='spectral', k=11, title='Spectral Glove k=11')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2c251982-6400-42cd-9717-784404956437" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c251982-6400-42cd-9717-784404956437")) {                    Plotly.newPlot(                        "2c251982-6400-42cd-9717-784404956437",                        [{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.17628740305670396)","width":2},"mode":"lines","showlegend":false,"x":[0.12435370917482824,-0.04760656756448656,null],"y":[0.36254226154325014,0.33506172252199184,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.28609803243322685)","width":2},"mode":"lines","showlegend":false,"x":[0.12435370917482824,0.2780788793236303,null],"y":[0.36254226154325014,0.40346757767027075,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.0)","width":2},"mode":"lines","showlegend":false,"x":[0.12435370917482824,0.20319553478487068,null],"y":[0.36254226154325014,0.5412105980619433,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.3350999331972103)","width":2},"mode":"lines","showlegend":false,"x":[0.12435370917482824,0.04493687658409709,null],"y":[0.36254226154325014,0.19624715515558835,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.052108030025666795)","width":2},"mode":"lines","showlegend":false,"x":[0.0012823379175920385,-0.011780871524810022,null],"y":[0.015586430749647617,-0.17317837420766763,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.11723803913014519)","width":2},"mode":"lines","showlegend":false,"x":[0.0012823379175920385,0.04493687658409709,null],"y":[0.015586430749647617,0.19624715515558835,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.5008901401154547)","width":2},"mode":"lines","showlegend":false,"x":[0.16199407649566108,-0.011780871524810022,null],"y":[-0.12325180553085524,-0.17317837420766763,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.2740625610338989)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,-0.04955048165903646,null],"y":[-0.34230983086100536,-0.3784487061613248,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.37270945617133516)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,0.010063537408377905,null],"y":[-0.34230983086100536,-0.3730245456223892,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.17941385867790052)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,-0.011355875072672937,null],"y":[-0.34230983086100536,-0.3053295539077045,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.06610343805628066)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,-0.011780871524810022,null],"y":[-0.34230983086100536,-0.17317837420766763,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.13258470873960873)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,0.034415327848521284,null],"y":[-0.34230983086100536,-0.2527635170256185,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.21557610509962968)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,-0.04589565218469377,null],"y":[-0.34230983086100536,-0.23657096541560166,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.04423679489580257)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,0.12076134868181015,null],"y":[-0.34230983086100536,-0.46283400405480607,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.12399039308990158)","width":2},"mode":"lines","showleg ...

# %% [markdown]
# > Looks worse than previous, too many clusters

# %%
build_graph(edges, method='louvin', title='Louvin Glove')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0a2d8e50-7853-4a6a-a2d9-96fe0d1e0607" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a2d8e50-7853-4a6a-a2d9-96fe0d1e0607")) {                    Plotly.newPlot(                        "0a2d8e50-7853-4a6a-a2d9-96fe0d1e0607",                        [{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.17628740305670396)","width":2},"mode":"lines","showlegend":false,"x":[0.12435370917482824,-0.04760656756448656,null],"y":[0.36254226154325014,0.33506172252199184,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.28609803243322685)","width":2},"mode":"lines","showlegend":false,"x":[0.12435370917482824,0.2780788793236303,null],"y":[0.36254226154325014,0.40346757767027075,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.0)","width":2},"mode":"lines","showlegend":false,"x":[0.12435370917482824,0.20319553478487068,null],"y":[0.36254226154325014,0.5412105980619433,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.3350999331972103)","width":2},"mode":"lines","showlegend":false,"x":[0.12435370917482824,0.04493687658409709,null],"y":[0.36254226154325014,0.19624715515558835,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.052108030025666795)","width":2},"mode":"lines","showlegend":false,"x":[0.0012823379175920385,-0.011780871524810022,null],"y":[0.015586430749647617,-0.17317837420766763,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.11723803913014519)","width":2},"mode":"lines","showlegend":false,"x":[0.0012823379175920385,0.04493687658409709,null],"y":[0.015586430749647617,0.19624715515558835,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.5008901401154547)","width":2},"mode":"lines","showlegend":false,"x":[0.16199407649566108,-0.011780871524810022,null],"y":[-0.12325180553085524,-0.17317837420766763,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.2740625610338989)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,-0.04955048165903646,null],"y":[-0.34230983086100536,-0.3784487061613248,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.37270945617133516)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,0.010063537408377905,null],"y":[-0.34230983086100536,-0.3730245456223892,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.17941385867790052)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,-0.011355875072672937,null],"y":[-0.34230983086100536,-0.3053295539077045,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.06610343805628066)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,-0.011780871524810022,null],"y":[-0.34230983086100536,-0.17317837420766763,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.13258470873960873)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,0.034415327848521284,null],"y":[-0.34230983086100536,-0.2527635170256185,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.21557610509962968)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,-0.04589565218469377,null],"y":[-0.34230983086100536,-0.23657096541560166,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.04423679489580257)","width":2},"mode":"lines","showlegend":false,"x":[0.10127254287880011,0.12076134868181015,null],"y":[-0.34230983086100536,-0.46283400405480607,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,255,0.12399039308990158)","width":2},"mode":"lines","showleg ...

# %% [markdown]
# > Very similar to the best of spectral clustering. It seems that some borderline cases are different.

# %% [markdown]
# > GloVe made it possible to draw a much more separable graph, so that clusters stand out very well, and they can be explained both in the case of spectral clustering and using the Louvin method

# %%
np.save('embeddings_glove', np.array(X_emb_3))
